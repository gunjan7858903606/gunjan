# %% [markdown]
# <a href="https://colab.research.google.com/github/gunjan7858903606/gunjan/blob/main/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # decision **tree**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.drop(columns=["User ID"],inplace=True)

# %%
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0    Male   19            19000          0
# 1    Male   35            20000          0
# 2  Female   26            43000          0
# 3  Female   27            57000          0
# 4    Male   19            76000          0

# %%
x=df.drop(columns=["Purchased"])
y=df["Purchased"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state = 24)
print(f"Shape of X_train {x_train.shape}")
print(f"Shape of y_train {y_train.shape}")
print(f"Shape of X_test {x_test.shape}")
print(f"Shape of y_test {y_test.shape}")
# Out:
# Shape of X_train (320, 3)
# Shape of y_train (320,)
# Shape of X_test (80, 3)
# Shape of y_test (80,)

# %%
x_train.head()
# Out:
#      Gender  Age  EstimatedSalary
# 105    Male   21            72000
# 17     Male   45            26000
# 64   Female   59            83000
# 349    Male   38            61000
# 116    Male   35            75000

# %%
x_train["Gender"].value_counts()
# Out:
# Female    164
# Male      156
# Name: Gender, dtype: int64

# %%
x_test["Gender"].value_counts()
# Out:
# Male      40
# Female    40
# Name: Gender, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
x_train["Gender"] = enc.fit_transform(x_train[["Gender"]])
x_test["Gender"] = enc.transform(x_test[["Gender"]])

# %%
x_train.head()
# Out:
#      Gender  Age  EstimatedSalary
# 105     1.0   21            72000
# 17      1.0   45            26000
# 64      0.0   59            83000
# 349     1.0   38            61000
# 116     1.0   35            75000

# %%
x_test.head()
# Out:
#      Gender  Age  EstimatedSalary
# 115     1.0   40            57000
# 186     0.0   20            82000
# 366     0.0   58            47000
# 81      1.0   39            42000
# 314     0.0   39            79000

# %%
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0    Male   19            19000          0
# 1    Male   35            20000          0
# 2  Female   26            43000          0
# 3  Female   27            57000          0
# 4    Male   19            76000          0

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320 entries, 105 to 387
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           320 non-null    float64
#  1   Age              320 non-null    int64
#  2   EstimatedSalary  320 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 10.0 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 115 to 267
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           80 non-null     float64
#  1   Age              80 non-null     int64
#  2   EstimatedSalary  80 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 2.5 KB

# %%
df["Gender"] = df.Gender.replace({"Female": 1, "Male" :0})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    int64
#  1   Age              400 non-null    int64
#  2   EstimatedSalary  400 non-null    int64
#  3   Purchased        400 non-null    int64
# dtypes: int64(4)
# memory usage: 12.6 KB

# %%
x = df.drop(columns = ["Purchased"])
y = df["Purchased"]

# %%
from sklearn.model_selection import train_test_split
# Train test split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=24)

print(f'Shape of X_train -: {x_train.shape}')
print(f'Shape of X_test -: {x_test.shape}')
print(f'Shape of y_train -: {y_train.shape}')
print(f'Shape of y_test -: {y_test.shape}')
# Out:
# Shape of X_train -: (320, 3)
# Shape of X_test -: (80, 3)
# Shape of y_train -: (320,)
# Shape of y_test -: (80,)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model = model.fit(x_train,y_train)

# %%
model.score(x_train,y_train)
# Out:
# 0.996875

# %%
model.score(x_test,y_test)
# Out:
# 0.8625

# %%
x_train.head()
# Out:
#      Gender  Age  EstimatedSalary
# 105       0   21            72000
# 17        0   45            26000
# 64        1   59            83000
# 349       0   38            61000
# 116       0   35            75000

# %%
x_train[~(x_train["Age"]<=41.5)]
# Out:
#      Gender  Age  EstimatedSalary
# 17        0   45            26000
# 64        1   59            83000
# 265       1   42           108000
# 298       0   45            79000
# 23        1   45            22000
# ..      ...  ...              ...
# 379       1   58            23000
# 227       0   56           133000
# 207       1   52           114000
# 356       0   54            70000
# 343       1   47            51000
#
# [103 rows x 3 columns]

# %%
y_train.value_counts()
# Out:
# 0    205
# 1    115
# Name: Purchased, dtype: int64

# %%
from sklearn.tree import plot_tree
figure = plt.figure(figsize=(30, 25))

plot_tree(model, filled=True)
plt.title("Decision tree trained on all the features")
plt.show()

# %%
model = DecisionTreeClassifier( max_depth = 3)
model = model.fit(x_train,y_train)

# %%
model.score(x_train,y_train)
# Out:
# 0.896875

# %%
model.score(x_test,y_test)
# Out:
# 0.9375

# %%
138/320
# Out:
# 0.43125

# %%
from sklearn.tree import plot_tree
figure=plt.figure(figsize=(30,25))
plot_tree(model,filled=True)
plt.title("Decisison tree trained on all the feutures")
plt.show()

# %%
x_train.head()
# Out:
#      Gender  Age  EstimatedSalary
# 105       0   21            72000
# 17        0   45            26000
# 64        1   59            83000
# 349       0   38            61000
# 116       0   35            75000

# %%
model.score(x_train,y_train)
# Out:
# 0.890625

# %%
model.score(x_test,y_test)
# Out:
# 0.925

# %%
model.feature_importances_
# Out:
# array([0.       , 0.6057324, 0.3942676])

# %%
x_train.columns
# Out:
# Index(['Gender', 'Age', 'EstimatedSalary'], dtype='object')

# %%
imp_df = pd.DataFrame({
    "Varname": x_train.columns,
    "Imp": model.feature_importances_
})

# %%
imp_df
# Out:
#            Varname       Imp
# 0           Gender  0.000000
# 1              Age  0.605732
# 2  EstimatedSalary  0.394268

# %%
imp_df.sort_values(by="Imp", ascending=False)
# Out:
#            Varname       Imp
# 1              Age  0.605732
# 2  EstimatedSalary  0.394268
# 0           Gender  0.000000

# %%
sns.barplot(data=imp_df.sort_values(by="Imp", ascending=False), x="Imp", y="Varname")
# Out:
# <Axes: xlabel='Imp', ylabel='Varname'>
