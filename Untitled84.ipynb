# %% [markdown]
# <a href="https://colab.research.google.com/github/gunjan7858903606/gunjan/blob/main/Untitled84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **pandas dataframes**

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({
    "Population" : [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    "GDP" : [1785387,2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075],
    "Surface" : [9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067],
      'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]

}, index = ['Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States'])

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.values
# Out:
# array([[35.467, 1785387, 9984670, 0.913, 'America'],
#        [63.951, 2833687, 640679, 0.888, 'Europe'],
#        [80.94, 3874437, 357114, 0.916, 'Europe'],
#        [60.665, 2167744, 301336, 0.873, 'Europe'],
#        [127.061, 4602367, 377930, 0.891, 'Asia'],
#        [64.511, 2950039, 242495, 0.907, 'Europe'],
#        [318.523, 17348075, 9525067, 0.915, 'America']], dtype=object)

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface', 'HDI', 'Continent'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  7 non-null      float64
#  1   GDP         7 non-null      int64
#  2   Surface     7 non-null      int64
#  3   HDI         7 non-null      float64
#  4   Continent   7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
df.dtypes
# Out:
# Population    float64
# GDP             int64
# Surface         int64
# HDI           float64
# Continent      object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull()
# Out:
#                 Population    GDP  Surface    HDI  Continent
# Canada               False  False    False  False      False
# France               False  False    False  False      False
# Germany              False  False    False  False      False
# Italy                False  False    False  False      False
# Japan                False  False    False  False      False
# United Kingdom       False  False    False  False      False
# United States        False  False    False  False      False

# %%
df.isnull().sum()
# Out:
# Population    0
# GDP           0
# Surface       0
# HDI           0
# Continent     0
# dtype: int64

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP       Surface       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df['HDI']
# Out:
# Canada            0.913
# France            0.888
# Germany           0.916
# Italy             0.873
# Japan             0.891
# United Kingdom    0.907
# United States     0.915
# Name: HDI, dtype: float64

# %%
df["GDP"]
# Out:
# Canada             1785387
# France             2833687
# Germany            3874437
# Italy              2167744
# Japan              4602367
# United Kingdom     2950039
# United States     17348075
# Name: GDP, dtype: int64

# %%
df.iloc[0]
# Out:
# Population     35.467
# GDP           1785387
# Surface       9984670
# HDI             0.913
# Continent     America
# Name: Canada, dtype: object

# %%
df.iloc[-2]
# Out:
# Population     64.511
# GDP           2950039
# Surface        242495
# HDI             0.907
# Continent      Europe
# Name: United Kingdom, dtype: object

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.loc["France"]
# Out:
# Population     63.951
# GDP           2833687
# Surface        640679
# HDI             0.888
# Continent      Europe
# Name: France, dtype: object

# %%
df.loc["Italy"]
# Out:
# Population     60.665
# GDP           2167744
# Surface        301336
# HDI             0.873
# Continent      Europe
# Name: Italy, dtype: object

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.iloc[0:4]
# Out:
#          Population      GDP  Surface    HDI Continent
# Canada       35.467  1785387  9984670  0.913   America
# France       63.951  2833687   640679  0.888    Europe
# Germany      80.940  3874437   357114  0.916    Europe
# Italy        60.665  2167744   301336  0.873    Europe

# %%
df.iloc[1:5]
# Out:
#          Population      GDP  Surface    HDI Continent
# France       63.951  2833687   640679  0.888    Europe
# Germany      80.940  3874437   357114  0.916    Europe
# Italy        60.665  2167744   301336  0.873    Europe
# Japan       127.061  4602367   377930  0.891      Asia

# %%
df.loc["France":"Italy"]
# Out:
#          Population      GDP  Surface    HDI Continent
# France       63.951  2833687   640679  0.888    Europe
# Germany      80.940  3874437   357114  0.916    Europe
# Italy        60.665  2167744   301336  0.873    Europe

# %%
df['Population'].to_frame()
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.loc["Canada" : "Germany", "Population": "Surface"]
# Out:
#          Population      GDP  Surface
# Canada       35.467  1785387  9984670
# France       63.951  2833687   640679
# Germany      80.940  3874437   357114

# %%
df.iloc[0:3,0:4]
# Out:
#          Population      GDP  Surface    HDI
# Canada       35.467  1785387  9984670  0.913
# France       63.951  2833687   640679  0.888
# Germany      80.940  3874437   357114  0.916

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df.iloc[1:5,1:4]
# Out:
#              GDP  Surface    HDI
# France   2833687   640679  0.888
# Germany  3874437   357114  0.916
# Italy    2167744   301336  0.873
# Japan    4602367   377930  0.891

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df[["Population", "Continent", "GDP"]]
# Out:
#                 Population Continent       GDP
# Canada              35.467   America   1785387
# France              63.951    Europe   2833687
# Germany             80.940    Europe   3874437
# Italy               60.665    Europe   2167744
# Japan              127.061      Asia   4602367
# United Kingdom      64.511    Europe   2950039
# United States      318.523   America  17348075

# %%
gunjan = df.copy()

# %%
gunjan
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
gunjan.drop(columns=["Population","GDP"],inplace = True)

# %%
gunjan
# Out:
#                 Surface    HDI Continent
# Canada          9984670  0.913   America
# France           640679  0.888    Europe
# Germany          357114  0.916    Europe
# Italy            301336  0.873    Europe
# Japan            377930  0.891      Asia
# United Kingdom   242495  0.907    Europe
# United States   9525067  0.915   America

# %%
df
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America
