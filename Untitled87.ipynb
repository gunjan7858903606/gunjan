# %% [markdown]
# <a href="https://colab.research.google.com/github/gunjan7858903606/gunjan/blob/main/Untitled87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **outlier detection**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("/content/all_seasons (2).csv")
df
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 0               0       Dennis Rodman               CHI  36.0         198.12
# 1               1   Dwayne Schintzius               LAC  28.0         215.90
# 2               2        Earl Cureton               TOR  39.0         205.74
# 3               3         Ed O'Bannon               DAL  24.0         203.20
# 4               4         Ed Pinckney               MIA  34.0         205.74
# ...           ...                 ...               ...   ...            ...
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                          NaN  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                          NaN      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round  ...  pts   reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0               2  ...  5.7  16.1  3.1        16.1     0.186     0.323
# 1               1  ...  2.3   1.5  0.3        12.3     0.078     0.151
# 2               3  ...  0.8   1.0  0.4        -2.1     0.105     0.102
# 3               1  ...  3.7   2.3  0.6        -8.7     0.060     0.149
# 4               1  ...  2.4   2.4  0.2       -11.2     0.109     0.179
# ...           ...  ...  ...   ...  ...         ...       ...       ...
# 11140   Undrafted  ...  9.1   5.4  1.1         4.6     0.056     0.140
# 11141           2  ...  1.2   0.3  0.1        -2.4     0.018     0.058
# 11142           1  ...  6.1   5.1  1.1         5.6     0.029     0.217
# 11143   Undrafted  ...  2.1   3.0  0.4       -16.4     0.085     0.237
# 11144   Undrafted  ...  4.5   1.4  0.5         1.0     0.017     0.104
#
#        usg_pct  ts_pct  ast_pct   season
# 0        0.100   0.479    0.113  1996-97
# 1        0.175   0.430    0.048  1996-97
# 2        0.103   0.376    0.148  1996-97
# 3        0.167   0.399    0.077  1996-97
# 4        0.127   0.611    0.040  1996-97
# ...        ...     ...      ...      ...
# 11140    0.136   0.605    0.064  2019-20
# 11141    0.164   0.480    0.033  2019-20
# 11142    0.120   0.640    0.076  2019-20
# 11143    0.126   0.521    0.056  2019-20
# 11144    0.149   0.663    0.089  2019-20
#
# [11145 rows x 22 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# player_name           object
# team_abbreviation     object
# age                  float64
# player_height        float64
# player_weight        float64
# college               object
# country               object
# draft_year            object
# draft_round           object
# draft_number          object
# gp                     int64
# pts                  float64
# reb                  float64
# ast                  float64
# net_rating           float64
# oreb_pct             float64
# dreb_pct             float64
# usg_pct              float64
# ts_pct               float64
# ast_pct              float64
# season                object
# dtype: object

# %%
df.shape
# Out:
# (11145, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11145 entries, 0 to 11144
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         11145 non-null  int64
#  1   player_name        11145 non-null  object
#  2   team_abbreviation  11145 non-null  object
#  3   age                11145 non-null  float64
#  4   player_height      11145 non-null  float64
#  5   player_weight      11145 non-null  float64
#  6   college            9461 non-null   object
#  7   country            11145 non-null  object
#  8   draft_year         11145 non-null  object
#  9   draft_round        11145 non-null  object
#  10  draft_number       11145 non-null  object
#  11  gp                 11145 non-null  int64
#  12  pts                11145 non-null  float64
#  13  reb                11145 non-null  float64
#  14  ast                11145 non-null  float64
#  15  net_rating         11145 non-null  float64
#  16  oreb_pct           11145 non-null  float64
#  17  dreb_pct           11145 non-null  float64
#  18  usg_pct            11145 non-null  float64
#  19  ts_pct             11145 non-null  float64
#  20  ast_pct            11145 non-null  float64
#  21  season             11145 non-null  object
# dtypes: float64(12), int64(2), object(8)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# player_name             0
# team_abbreviation       0
# age                     0
# player_height           0
# player_weight           0
# college              1684
# country                 0
# draft_year              0
# draft_round             0
# draft_number            0
# gp                      0
# pts                     0
# reb                     0
# ast                     0
# net_rating              0
# oreb_pct                0
# dreb_pct                0
# usg_pct                 0
# ts_pct                  0
# ast_pct                 0
# season                  0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0           age  player_height  player_weight            gp  \
# count  11145.000000  11145.000000   11145.000000   11145.000000  11145.000000
# mean    5572.000000     27.168686     200.812818     100.637868     52.005832
# std     3217.428709      4.344164       9.190973      12.576295     25.069495
# min        0.000000     18.000000     160.020000      60.327736      1.000000
# 25%     2786.000000     24.000000     195.580000      90.718400     32.000000
# 50%     5572.000000     27.000000     200.660000      99.790240     58.000000
# 75%     8358.000000     30.000000     208.280000     109.315672     74.000000
# max    11144.000000     44.000000     231.140000     163.293120     85.000000
#
#                 pts           reb           ast    net_rating      oreb_pct  \
# count  11145.000000  11145.000000  11145.000000  11145.000000  11145.000000
# mean       8.126487      3.560036      1.801463     -2.153899      0.055593
# std        5.935482      2.495394      1.789940     12.150611      0.043889
# min        0.000000      0.000000      0.000000   -200.000000      0.000000
# 25%        3.500000      1.800000      0.600000     -6.300000      0.022000
# 50%        6.600000      3.000000      1.200000     -1.300000      0.043000
# 75%       11.500000      4.700000      2.400000      3.200000      0.086000
# max       36.100000     16.300000     11.700000    300.000000      1.000000
#
#            dreb_pct       usg_pct        ts_pct       ast_pct
# count  11145.000000  11145.000000  11145.000000  11145.000000
# mean       0.141772      0.185599      0.508099      0.131078
# std        0.063194      0.053047      0.098879      0.095017
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.096000      0.150000      0.478000      0.065000
# 50%        0.132000      0.182000      0.521000      0.102000
# 75%        0.182000      0.218000      0.557000      0.178000
# max        1.000000      1.000000      1.500000      1.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
df
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 0               0       Dennis Rodman               CHI  36.0         198.12
# 1               1   Dwayne Schintzius               LAC  28.0         215.90
# 2               2        Earl Cureton               TOR  39.0         205.74
# 3               3         Ed O'Bannon               DAL  24.0         203.20
# 4               4         Ed Pinckney               MIA  34.0         205.74
# ...           ...                 ...               ...   ...            ...
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                          NaN  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                          NaN      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round  ...  pts   reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0               2  ...  5.7  16.1  3.1        16.1     0.186     0.323
# 1               1  ...  2.3   1.5  0.3        12.3     0.078     0.151
# 2               3  ...  0.8   1.0  0.4        -2.1     0.105     0.102
# 3               1  ...  3.7   2.3  0.6        -8.7     0.060     0.149
# 4               1  ...  2.4   2.4  0.2       -11.2     0.109     0.179
# ...           ...  ...  ...   ...  ...         ...       ...       ...
# 11140   Undrafted  ...  9.1   5.4  1.1         4.6     0.056     0.140
# 11141           2  ...  1.2   0.3  0.1        -2.4     0.018     0.058
# 11142           1  ...  6.1   5.1  1.1         5.6     0.029     0.217
# 11143   Undrafted  ...  2.1   3.0  0.4       -16.4     0.085     0.237
# 11144   Undrafted  ...  4.5   1.4  0.5         1.0     0.017     0.104
#
#        usg_pct  ts_pct  ast_pct   season
# 0        0.100   0.479    0.113  1996-97
# 1        0.175   0.430    0.048  1996-97
# 2        0.103   0.376    0.148  1996-97
# 3        0.167   0.399    0.077  1996-97
# 4        0.127   0.611    0.040  1996-97
# ...        ...     ...      ...      ...
# 11140    0.136   0.605    0.064  2019-20
# 11141    0.164   0.480    0.033  2019-20
# 11142    0.120   0.640    0.076  2019-20
# 11143    0.126   0.521    0.056  2019-20
# 11144    0.149   0.663    0.089  2019-20
#
# [11145 rows x 22 columns]

# %%
df.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
df
# Out:
#               player_name team_abbreviation   age  player_height  \
# 0           Dennis Rodman               CHI  36.0         198.12
# 1       Dwayne Schintzius               LAC  28.0         215.90
# 2            Earl Cureton               TOR  39.0         205.74
# 3             Ed O'Bannon               DAL  24.0         203.20
# 4             Ed Pinckney               MIA  34.0         205.74
# ...                   ...               ...   ...            ...
# 11140         Maxi Kleber               DAL  28.0         208.28
# 11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142      Meyers Leonard               MIA  28.0         213.36
# 11143        Norvel Pelle               PHI  27.0         208.28
# 11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                          NaN  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                          NaN      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round draft_number  ...  pts   reb  ast  net_rating  oreb_pct  \
# 0               2           27  ...  5.7  16.1  3.1        16.1     0.186
# 1               1           24  ...  2.3   1.5  0.3        12.3     0.078
# 2               3           58  ...  0.8   1.0  0.4        -2.1     0.105
# 3               1            9  ...  3.7   2.3  0.6        -8.7     0.060
# 4               1           10  ...  2.4   2.4  0.2       -11.2     0.109
# ...           ...          ...  ...  ...   ...  ...         ...       ...
# 11140   Undrafted    Undrafted  ...  9.1   5.4  1.1         4.6     0.056
# 11141           2           35  ...  1.2   0.3  0.1        -2.4     0.018
# 11142           1           11  ...  6.1   5.1  1.1         5.6     0.029
# 11143   Undrafted    Undrafted  ...  2.1   3.0  0.4       -16.4     0.085
# 11144   Undrafted    Undrafted  ...  4.5   1.4  0.5         1.0     0.017
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 0         0.323    0.100   0.479    0.113  1996-97
# 1         0.151    0.175   0.430    0.048  1996-97
# 2         0.102    0.103   0.376    0.148  1996-97
# 3         0.149    0.167   0.399    0.077  1996-97
# 4         0.179    0.127   0.611    0.040  1996-97
# ...         ...      ...     ...      ...      ...
# 11140     0.140    0.136   0.605    0.064  2019-20
# 11141     0.058    0.164   0.480    0.033  2019-20
# 11142     0.217    0.120   0.640    0.076  2019-20
# 11143     0.237    0.126   0.521    0.056  2019-20
# 11144     0.104    0.149   0.663    0.089  2019-20
#
# [11145 rows x 21 columns]

# %%
df["player_weight"].describe()
# Out:
# count    11145.000000
# mean       100.637868
# std         12.576295
# min         60.327736
# 25%         90.718400
# 50%         99.790240
# 75%        109.315672
# max        163.293120
# Name: player_weight, dtype: float64

# %%
import plotly.express as px

fig = px.box(df, x="player_weight", width=900, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8186c9f3-aa35-479e-9eec-423ca8300c78" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8186c9f3-aa35-479e-9eec-423ca8300c78")) {                    Plotly.newPlot(                        "8186c9f3-aa35-479e-9eec-423ca8300c78",                        [{"alignmentgroup":"True","hovertemplate":"player_weight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[99.79024,117.93392,95.25432,100.697424,108.86208,97.52228,86.18248,113.398,86.18248,72.57472,77.11064,122.46984,87.996848,80.28578399999998,120.20188,106.59412,122.46984,86.18248,97.52228,90.7184,99.79024,120.20188,95.25432,111.13004,97.52228,108.86208,99.79024,86.18248,92.98636,106.59412,90.7184,93.439952,108.86208,102.0582,117.93392,92.98636,106.59412,108.86208,83.91452,

# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data = df[["player_weight","age","player_height"]], kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
df["age"].skew()
# Out:
# 0.5458567811632224

# %%
df["player_height"].skew()
# Out:
# -0.3775857815158464

# %%
df["player_weight"].skew()
# Out:
# 0.1469057175740028

# %%
df["player_weight"].describe()
# Out:
# count    11145.000000
# mean       100.637868
# std         12.576295
# min         60.327736
# 25%         90.718400
# 50%         99.790240
# 75%        109.315672
# max        163.293120
# Name: player_weight, dtype: float64

# %%
df
# Out:
#               player_name team_abbreviation   age  player_height  \
# 0           Dennis Rodman               CHI  36.0         198.12
# 1       Dwayne Schintzius               LAC  28.0         215.90
# 2            Earl Cureton               TOR  39.0         205.74
# 3             Ed O'Bannon               DAL  24.0         203.20
# 4             Ed Pinckney               MIA  34.0         205.74
# ...                   ...               ...   ...            ...
# 11140         Maxi Kleber               DAL  28.0         208.28
# 11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142      Meyers Leonard               MIA  28.0         213.36
# 11143        Norvel Pelle               PHI  27.0         208.28
# 11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                          NaN  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                          NaN      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round draft_number  ...  pts   reb  ast  net_rating  oreb_pct  \
# 0               2           27  ...  5.7  16.1  3.1        16.1     0.186
# 1               1           24  ...  2.3   1.5  0.3        12.3     0.078
# 2               3           58  ...  0.8   1.0  0.4        -2.1     0.105
# 3               1            9  ...  3.7   2.3  0.6        -8.7     0.060
# 4               1           10  ...  2.4   2.4  0.2       -11.2     0.109
# ...           ...          ...  ...  ...   ...  ...         ...       ...
# 11140   Undrafted    Undrafted  ...  9.1   5.4  1.1         4.6     0.056
# 11141           2           35  ...  1.2   0.3  0.1        -2.4     0.018
# 11142           1           11  ...  6.1   5.1  1.1         5.6     0.029
# 11143   Undrafted    Undrafted  ...  2.1   3.0  0.4       -16.4     0.085
# 11144   Undrafted    Undrafted  ...  4.5   1.4  0.5         1.0     0.017
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 0         0.323    0.100   0.479    0.113  1996-97
# 1         0.151    0.175   0.430    0.048  1996-97
# 2         0.102    0.103   0.376    0.148  1996-97
# 3         0.149    0.167   0.399    0.077  1996-97
# 4         0.179    0.127   0.611    0.040  1996-97
# ...         ...      ...     ...      ...      ...
# 11140     0.140    0.136   0.605    0.064  2019-20
# 11141     0.058    0.164   0.480    0.033  2019-20
# 11142     0.217    0.120   0.640    0.076  2019-20
# 11143     0.237    0.126   0.521    0.056  2019-20
# 11144     0.104    0.149   0.663    0.089  2019-20
#
# [11145 rows x 21 columns]

# %%
df["player_weight"].mean(), df["player_height"].std()
# Out:
# (100.63786774840734, 9.190973456084304)

# %%
(df["player_weight"] - df["player_weight"].mean())/ df["player_weight"].std()
# Out:
# 0       -0.067399
# 1        1.375290
# 2       -0.428071
# 3        0.004736
# 4        0.653946
#            ...
# 11140    0.653946
# 11141   -0.247735
# 11142    1.375290
# 11143    0.329341
# 11144   -1.149415
# Name: player_weight, Length: 11145, dtype: float64

# %%
df["z_score_player_weight"] = (df["player_weight"] - df["player_weight"].mean())/ df["player_weight"].std()

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
#    ...   reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# 0  ...  16.1  3.1        16.1     0.186     0.323    0.100   0.479    0.113
# 1  ...   1.5  0.3        12.3     0.078     0.151    0.175   0.430    0.048
# 2  ...   1.0  0.4        -2.1     0.105     0.102    0.103   0.376    0.148
# 3  ...   2.3  0.6        -8.7     0.060     0.149    0.167   0.399    0.077
# 4  ...   2.4  0.2       -11.2     0.109     0.179    0.127   0.611    0.040
#
#     season  z_score_player_weight
# 0  1996-97              -0.067399
# 1  1996-97               1.375290
# 2  1996-97              -0.428071
# 3  1996-97               0.004736
# 4  1996-97               0.653946
#
# [5 rows x 22 columns]

# %%
df[(df["z_score_player_weight"] > 3) | (df["z_score_player_weight"] < -3)]
# Out:
#              player_name team_abbreviation   age  player_height  \
# 331    Priest Lauderdale               ATL  23.0         223.52
# 406        Oliver Miller               TOR  27.0         205.74
# 469    Priest Lauderdale               DEN  24.0         223.52
# 480        Oliver Miller               TOR  28.0         205.74
# 641            Spud Webb               ORL  34.0         167.64
# 650     Shaquille O'Neal               LAL  26.0         215.90
# 1059    Shaquille O'Neal               LAL  27.0         215.90
# 1161       Oliver Miller               SAC  29.0         205.74
# 1326        Earl Boykins               CLE  24.0         165.10
# 1556    Shaquille O'Neal               LAL  28.0         215.90
# 1629     Thomas Hamilton               HOU  25.0         218.44
# 1711       Oliver Miller               PHX  30.0         205.74
# 1784        Earl Boykins               LAC  25.0         165.10
# 1799        Garth Joseph               DEN  27.0         218.44
# 2020       Muggsy Bogues               TOR  36.0         160.02
# 2177    Shaquille O'Neal               LAL  29.0         215.90
# 2405    Shaquille O'Neal               LAL  30.0         215.90
# 2590        Earl Boykins               LAC  26.0         165.10
# 2805        Earl Boykins               GSW  27.0         165.10
# 2866    Shaquille O'Neal               LAL  31.0         215.90
# 3110       Oliver Miller               MIN  34.0         205.74
# 3211            Yao Ming               HOU  23.0         228.60
# 3268    Shaquille O'Neal               LAL  32.0         215.90
# 3462        Earl Boykins               DEN  28.0         165.10
# 3662            Yao Ming               HOU  24.0         228.60
# 3718    Shaquille O'Neal               MIA  33.0         215.90
# 3923        Earl Boykins               DEN  29.0         165.10
# 4122            Yao Ming               HOU  25.0         228.60
# 4173    Shaquille O'Neal               MIA  34.0         215.90
# 4427        Earl Boykins               DEN  30.0         165.10
# 4484        Earl Boykins               MIL  31.0         165.10
# 4686    Shaquille O'Neal               MIA  35.0         215.90
# 4741            Yao Ming               HOU  26.0         228.60
# 4888        Earl Boykins               CHA  32.0         165.10
# 5254            Yao Ming               HOU  27.0         228.60
# 5276    Shaquille O'Neal               PHX  36.0         215.90
# 5700            Yao Ming               HOU  28.0         228.60
# 5716    Shaquille O'Neal               PHX  37.0         215.90
# 5925        Earl Boykins               WAS  34.0         165.10
# 6031    Shaquille O'Neal               CLE  38.0         215.90
# 6449        Earl Boykins               MIL  35.0         165.10
# 6451      Dexter Pittman               MIA  23.0         210.82
# 6569    Shaquille O'Neal               BOS  39.0         215.90
# 6582            Yao Ming               HOU  30.0         228.60
# 6692        Earl Boykins               HOU  36.0         165.10
# 8472         Sim Bhullar               SAC  22.0         226.06
# 8699      Nikola Pekovic               MIN  30.0         210.82
# 10950         Tacko Fall               BOS  24.0         226.06
#
#        player_weight               college     country draft_year draft_round  \
# 331       155.582056    Central State (OH)         USA       1996           1
# 406       140.613520              Arkansas         USA       1992           1
# 469       147.417400    Central State (OH)         USA       1996           1
# 480       147.417400              Arkansas         USA       1992           1
# 641        60.327736  North Carolina State         USA       1985           4
# 650       142.881480       Louisiana State         USA       1992           1
# 1059      142.881480       Louisiana State         USA       1992           1
# 1161      147.417400              Arkansas         USA       1992           1
# 1326       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 1556      142.881480       Louisiana State         USA       1992           1
# 1629      149.685360            Pittsburgh         USA  Undrafted   Undrafted
# 1711      142.881480              Arkansas         USA       1992           1
# 1784       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 1799      138.799152            Saint Rose         USA  Undrafted   Undrafted
# 2020       61.688512           Wake Forest         USA       1987           1
# 2177      142.881480       Louisiana State         USA       1992           1
# 2405      142.881480       Louisiana State         USA       1992           1
# 2590       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 2805       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 2866      151.953320       Louisiana State         USA       1992           1
# 3110      142.881480              Arkansas         USA       1992           1
# 3211      140.613520                   NaN       China       2002           1
# 3268      154.221280       Louisiana State         USA       1992           1
# 3462       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 3662      140.613520                   NaN       China       2002           1
# 3718      147.417400       Louisiana State         USA       1992           1
# 3923       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 4122      140.613520                   NaN       China       2002           1
# 4173      147.417400       Louisiana State         USA       1992           1
# 4427       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 4484       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 4686      147.417400       Louisiana State         USA       1992           1
# 4741      140.613520                   NaN       China       2002           1
# 4888       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 5254      140.613520                   NaN       China       2002           1
# 5276      147.417400       Louisiana State         USA       1992           1
# 5700      140.613520                   NaN       China       2002           1
# 5716      147.417400       Louisiana State         USA       1992           1
# 5925       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 6031      147.417400       Louisiana State         USA       1992           1
# 6449       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 6451      139.706336                 Texas         USA       2010           2
# 6569      147.417400       Louisiana State         USA       1992           1
# 6582      140.613520                   NaN       China       2002           1
# 6692       60.327736      Eastern Michigan         USA  Undrafted   Undrafted
# 8472      163.293120      New Mexico State      Canada  Undrafted   Undrafted
# 8699      139.252744                   NaN  Montenegro       2008           2
# 10950     141.067112                   NaN     Senegal  Undrafted   Undrafted
#
#       draft_number  ...   reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  \
# 331             28  ...   1.2  0.3        -4.0     0.093     0.164    0.284
# 406             22  ...   5.0  1.4        -1.0     0.107     0.204    0.141
# 469             28  ...   2.6  0.5        -6.2     0.093     0.251    0.268
# 480             22  ...   6.3  3.1        -9.9     0.099     0.177    0.149
# 641             87  ...   0.8  1.3       -24.6     0.067     0.038    0.252
# 650              1  ...  11.4  2.4        15.6     0.114     0.236    0.331
# 1059             1  ...  10.7  2.3         6.4     0.135     0.227    0.325
# 1161            22  ...   2.0  0.0       -18.8     0.194     0.038    0.177
# 1326     Undrafted  ...   1.0  1.8       -11.8     0.046     0.076    0.245
# 1556             1  ...  13.6  3.8        11.0     0.116     0.246    0.313
# 1629     Undrafted  ...   4.1  0.7        -8.0     0.129     0.274    0.187
# 1711            22  ...   5.1  1.3         6.0     0.093     0.167    0.137
# 1784     Undrafted  ...   1.1  3.2        -6.4     0.029     0.055    0.235
# 1799     Undrafted  ...   0.5  0.3       -35.0     0.111     0.000    0.211
# 2020            12  ...   1.0  1.7       -27.4     0.000     0.120    0.078
# 2177             1  ...  12.7  3.7         7.9     0.116     0.247    0.318
# 2405             1  ...  10.7  3.0        11.5     0.110     0.211    0.318
# 2590     Undrafted  ...   0.8  2.1        -0.5     0.040     0.041    0.202
# 2805     Undrafted  ...   1.3  3.3         3.1     0.029     0.044    0.206
# 2866             1  ...  11.1  3.1         6.9     0.120     0.214    0.303
# 3110            22  ...   2.7  0.8         0.6     0.115     0.180    0.135
# 3211             1  ...   9.0  1.5         3.6     0.093     0.220    0.252
# 3268             1  ...  11.5  2.9         8.3     0.114     0.232    0.260
# 3462     Undrafted  ...   1.7  3.6        -0.1     0.025     0.063    0.224
# 3662             1  ...   8.4  0.8         2.0     0.102     0.215    0.264
# 3718             1  ...  10.4  2.7        10.8     0.124     0.224    0.303
# 3923     Undrafted  ...   1.7  4.5         1.9     0.019     0.057    0.220
# 4122             1  ...  10.2  1.5         1.4     0.093     0.248    0.298
# 4173             1  ...   9.2  1.9         6.9     0.121     0.232    0.299
# 4427     Undrafted  ...   1.4  3.8        -3.3     0.015     0.047    0.234
# 4484     Undrafted  ...   2.1  4.4        -5.9     0.026     0.050    0.213
# 4686             1  ...   7.4  2.0         2.6     0.102     0.209    0.302
# 4741             1  ...   9.4  2.0         9.3     0.076     0.238    0.331
# 4888     Undrafted  ...   0.9  2.7        -6.6     0.017     0.052    0.190
# 6582    0.579    0.077  2010-11               3.178651
# 6692    0.458    0.274  2011-12              -3.205247
# 8472    0.500    0.500  2014-15               4.982012
# 8699    0.459    0.131  2015-16               3.070449
# 10950   0.713    0.000  2019-20               3.214718
#
# [48 rows x 22 columns]

# %%
df.shape
# Out:
# (11145, 22)

# %%
df_without_outlier = df[~((df["z_score_player_weight"] > 3) | (df["z_score_player_weight"] < -3))]

# %%
df_without_outlier
# Out:
#               player_name team_abbreviation   age  player_height  \
# 0           Dennis Rodman               CHI  36.0         198.12
# 1       Dwayne Schintzius               LAC  28.0         215.90
# 2            Earl Cureton               TOR  39.0         205.74
# 3             Ed O'Bannon               DAL  24.0         203.20
# 4             Ed Pinckney               MIA  34.0         205.74
# ...                   ...               ...   ...            ...
# 11140         Maxi Kleber               DAL  28.0         208.28
# 11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142      Meyers Leonard               MIA  28.0         213.36
# 11143        Norvel Pelle               PHI  27.0         208.28
# 11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                          NaN  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                          NaN      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round draft_number  ...   reb  ast  net_rating  oreb_pct  \
# 0               2           27  ...  16.1  3.1        16.1     0.186
# 1               1           24  ...   1.5  0.3        12.3     0.078
# 2               3           58  ...   1.0  0.4        -2.1     0.105
# 3               1            9  ...   2.3  0.6        -8.7     0.060
# 4               1           10  ...   2.4  0.2       -11.2     0.109
# ...           ...          ...  ...   ...  ...         ...       ...
# 11140   Undrafted    Undrafted  ...   5.4  1.1         4.6     0.056
# 11141           2           35  ...   0.3  0.1        -2.4     0.018
# 11142           1           11  ...   5.1  1.1         5.6     0.029
# 11143   Undrafted    Undrafted  ...   3.0  0.4       -16.4     0.085
# 11144   Undrafted    Undrafted  ...   1.4  0.5         1.0     0.017
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season  z_score_player_weight
# 0         0.323    0.100   0.479    0.113  1996-97              -0.067399
# 1         0.151    0.175   0.430    0.048  1996-97               1.375290
# 2         0.102    0.103   0.376    0.148  1996-97              -0.428071
# 3         0.149    0.167   0.399    0.077  1996-97               0.004736
# 4         0.179    0.127   0.611    0.040  1996-97               0.653946
# ...         ...      ...     ...      ...      ...                    ...
# 11140     0.140    0.136   0.605    0.064  2019-20               0.653946
# 11141     0.058    0.164   0.480    0.033  2019-20              -0.247735
# 11142     0.217    0.120   0.640    0.076  2019-20               1.375290
# 11143     0.237    0.126   0.521    0.056  2019-20               0.329341
# 11144     0.104    0.149   0.663    0.089  2019-20              -1.149415
#
# [11097 rows x 22 columns]

# %%
c.shape
# Out:
# (11097, 22)

# %%
sns.histplot(data = df_without_outlier["player_weight"], kde =True)
# Out:
# <Axes: xlabel='player_weight', ylabel='Count'>

# %%
df_without_outlier.player_weight.skew()
# Out:
# 0.07188666926628842

# %%
import plotly.express as px
px.box(df_without_outlier, x = "player_weight")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e
101.604608,84.821704,88.45044,83.91452,97.52228,86.0,114.758776,88.45044,111.13004,112.944408,117.93392,97.52228,120.20188,99.79024,86.18248,110.676448,113.398,83.91452,115.66596,86.18248,109.315672,92.98636,131.54168,90.7184,103.418976,82.553744,106.59412,102.0582,111.13004,68.945984,86.18248,111.13004,106.59412,90.7184,92.98636,127.00576,92.98636,104.32616,104.32616,117.93392,88.45044,108.86208,90.7184,95.25432,98.883056,120.20188,111.13004,117.93392,113.398,113.398,85.728888,111.13004,81.64656,111.13004,81.64656,88.45044,113.398,97.52228,94.347136,117.93392,81.64656,113.398,86.18248,86.18248,88.45044,102.0582,88.45044,111.13004,90.7184,85.275296,115.66596,99.79024,108.86208,102.0582,105.233344,113.398,83.91452,81.64656,136 ...

# %%
sns.histplot(data = df["age"], kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df_without_outlier["age"].skew()
# Out:
# 0.5468489789430716

# %%
df["z_score_age"] = (df["age"] - df["age"].mean())/ df["age"].std()

# %%
df
# Out:
#               player_name team_abbreviation   age  player_height  \
# 0           Dennis Rodman               CHI  36.0         198.12
# 1       Dwayne Schintzius               LAC  28.0         215.90
# 2            Earl Cureton               TOR  39.0         205.74
# 3             Ed O'Bannon               DAL  24.0         203.20
# 4             Ed Pinckney               MIA  34.0         205.74
# ...                   ...               ...   ...            ...
# 11140         Maxi Kleber               DAL  28.0         208.28
# 11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142      Meyers Leonard               MIA  28.0         213.36
# 11143        Norvel Pelle               PHI  27.0         208.28
# 11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                          NaN  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                          NaN      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round draft_number  ...  ast  net_rating  oreb_pct  dreb_pct  \
# 0               2           27  ...  3.1        16.1     0.186     0.323
# 1               1           24  ...  0.3        12.3     0.078     0.151
# 2               3           58  ...  0.4        -2.1     0.105     0.102
# 3               1            9  ...  0.6        -8.7     0.060     0.149
# 4               1           10  ...  0.2       -11.2     0.109     0.179
# ...           ...          ...  ...  ...         ...       ...       ...
# 11140   Undrafted    Undrafted  ...  1.1         4.6     0.056     0.140
# 11141           2           35  ...  0.1        -2.4     0.018     0.058
# 11142           1           11  ...  1.1         5.6     0.029     0.217
# 11143   Undrafted    Undrafted  ...  0.4       -16.4     0.085     0.237
# 11144   Undrafted    Undrafted  ...  0.5         1.0     0.017     0.104
#
#        usg_pct  ts_pct  ast_pct   season  z_score_player_weight  z_score_age
# 0        0.100   0.479    0.113  1996-97              -0.067399     2.032915
# 1        0.175   0.430    0.048  1996-97               1.375290     0.191364
# 2        0.103   0.376    0.148  1996-97              -0.428071     2.723496
# 3        0.167   0.399    0.077  1996-97               0.004736    -0.729412
# 4        0.127   0.611    0.040  1996-97               0.653946     1.572527
# ...        ...     ...      ...      ...                    ...          ...
# 11140    0.136   0.605    0.064  2019-20               0.653946     0.191364
# 11141    0.164   0.480    0.033  2019-20              -0.247735    -0.959606
# 11142    0.120   0.640    0.076  2019-20               1.375290     0.191364
# 11143    0.126   0.521    0.056  2019-20               0.329341    -0.038830
# 11144    0.149   0.663    0.089  2019-20              -1.149415    -0.499218
#
# [11145 rows x 23 columns]

# %%
df[(df["z_score_age"] > 3) | (df["z_score_age"] < -3)]
# Out:
#            player_name team_abbreviation   age  player_height  player_weight  \
# 270      Robert Parish               CHI  43.0         215.90     110.676448
# 730      Charles Jones               HOU  41.0         205.74      97.522280
# 1289     Herb Williams               NYK  41.0         210.82     117.933920
# 2824     John Stockton               UTA  41.0         185.42      79.378600
# 3144      Kevin Willis               SAS  41.0         213.36     111.130040
# 3575      Kevin Willis               ATL  42.0         213.36     111.130040
# 4473   Dikembe Mutombo               HOU  41.0         218.44     117.933920
# 4820      Kevin Willis               DAL  44.0         213.36     111.130040
# 4937   Dikembe Mutombo               HOU  42.0         218.44     117.933920
# 5365   Dikembe Mutombo               HOU  43.0         218.44     117.933920
# 9839      Vince Carter               SAC  41.0         198.12      99.790240
# 10320    Dirk Nowitzki               DAL  41.0         213.36     111.130040
# 10435     Vince Carter               ATL  42.0         198.12      99.790240
# 10960     Vince Carter               ATL  43.0         198.12      99.790240
#
#                  college  country draft_year draft_round draft_number  ...  \
# 270       Centenary (LA)      USA       1976           1            8  ...
# 730    Albany State (GA)      USA       1979           8          165  ...
# 1289          Ohio State      USA       1981           1           14  ...
# 2824             Gonzaga      USA       1984           1           16  ...
# 3144      Michigan State      USA       1984           1           11  ...
# 3575      Michigan State      USA       1984           1           11  ...
# 4473          Georgetown    Congo       1991           1            4  ...
# 4820      Michigan State      USA       1984           1           11  ...
# 4937          Georgetown    Congo       1991           1            4  ...
# 5365          Georgetown    Congo       1991           1            4  ...
# 9839      North Carolina      USA       1998           1            5  ...
# 10320                NaN  Germany       1998           1            9  ...
# 10435     North Carolina      USA       1998           1            5  ...
# 10960     North Carolina      USA       1998           1            5  ...
#
#        ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct   season  \
# 270    0.5        14.9     0.114     0.130    0.201   0.514    0.082  1996-97
# 730    0.2        -6.2     0.098     0.111    0.049   0.689    0.055  1997-98
# 1289   0.0         0.9     0.088     0.103    0.138   0.563    0.000  1998-99
# 2824   7.7         5.2     0.028     0.078    0.191   0.577    0.445  2002-03
# 3144   0.2        -0.9     0.108     0.182    0.244   0.491    0.059  2003-04
# 3575   0.3       -15.5     0.091     0.164    0.151   0.434    0.043  2004-05
# 4473   0.2         5.8     0.143     0.282    0.084   0.601    0.016  2006-07
# 4820   0.2        11.9     0.063     0.222    0.184   0.432    0.034  2006-07
# 4937   0.1         3.6     0.118     0.221    0.086   0.591    0.012  2007-08
# 5365   0.0         1.8     0.152     0.241    0.111   0.472    0.000  2008-09
# 9839   1.2        -3.3     0.017     0.130    0.144   0.523    0.099  2017-18
# 10320  0.7        -4.8     0.006     0.180    0.217   0.469    0.068  2018-19
# 10435  1.1        -6.3     0.021     0.114    0.164   0.565    0.097  2018-19
# 10960  0.8        -8.6     0.019     0.116    0.163   0.464    0.082  2019-20
#
#        z_score_player_weight  z_score_age
# 270                 0.798214     3.644272
# 730                -0.247735     3.183884
# 1289                1.375290     3.183884
# 2824               -1.690424     3.183884
# 3144                0.834282     3.183884
# 3575                0.834282     3.414078
# 4473                1.375290     3.183884
# 4820                0.834282     3.874466
# 4937                1.375290     3.414078
# 5365                1.375290     3.644272
# 9839               -0.067399     3.183884
# 10320               0.834282     3.183884
# 10435              -0.067399     3.414078
# 10960              -0.067399     3.644272
#
# [14 rows x 23 columns]

# %%
df_without_outlier = df[~((df["z_score_age"] > 3) | (df["z_score_age"] < -3))]

# %%
df_without_outlier.shape
# Out:
# (11131, 23)

# %%
df_without_outlier
# Out:
#               player_name team_abbreviation   age  player_height  \
# 0           Dennis Rodman               CHI  36.0         198.12
# 1       Dwayne Schintzius               LAC  28.0         215.90
# 2            Earl Cureton               TOR  39.0         205.74
# 3             Ed O'Bannon               DAL  24.0         203.20
# 4             Ed Pinckney               MIA  34.0         205.74
# ...                   ...               ...   ...            ...
# 11140         Maxi Kleber               DAL  28.0         208.28
# 11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142      Meyers Leonard               MIA  28.0         213.36
# 11143        Norvel Pelle               PHI  27.0         208.28
# 11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                          NaN  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                          NaN      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round draft_number  ...  ast  net_rating  oreb_pct  dreb_pct  \
# 0               2           27  ...  3.1        16.1     0.186     0.323
# 1               1           24  ...  0.3        12.3     0.078     0.151
# 2               3           58  ...  0.4        -2.1     0.105     0.102
# 3               1            9  ...  0.6        -8.7     0.060     0.149
# 4               1           10  ...  0.2       -11.2     0.109     0.179
# ...           ...          ...  ...  ...         ...       ...       ...
# 11140   Undrafted    Undrafted  ...  1.1         4.6     0.056     0.140
# 11141           2           35  ...  0.1        -2.4     0.018     0.058
# 11142           1           11  ...  1.1         5.6     0.029     0.217
# 11143   Undrafted    Undrafted  ...  0.4       -16.4     0.085     0.237
# 11144   Undrafted    Undrafted  ...  0.5         1.0     0.017     0.104
#
#        usg_pct  ts_pct  ast_pct   season  z_score_player_weight  z_score_age
# 0        0.100   0.479    0.113  1996-97              -0.067399     2.032915
# 1        0.175   0.430    0.048  1996-97               1.375290     0.191364
# 2        0.103   0.376    0.148  1996-97              -0.428071     2.723496
# 3        0.167   0.399    0.077  1996-97               0.004736    -0.729412
# 4        0.127   0.611    0.040  1996-97               0.653946     1.572527
# ...        ...     ...      ...      ...                    ...          ...
# 11140    0.136   0.605    0.064  2019-20               0.653946     0.191364
# 11141    0.164   0.480    0.033  2019-20              -0.247735    -0.959606
# 11142    0.120   0.640    0.076  2019-20               1.375290     0.191364
# 11143    0.126   0.521    0.056  2019-20               0.329341    -0.038830
# 11144    0.149   0.663    0.089  2019-20              -1.149415    -0.499218
#
# [11131 rows x 23 columns]

# %%
sns.histplot(data = df_without_outlier["age"], kde =True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
px.box(df_without_outlier, x = "age")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="27c2b225-77f1-43f7-9137-1e3589f38128" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27c2b225-77f1-43f7-9137-1e3589f38128")) {                    Plotly.newPlot(                        "27c2b225-77f1-43f7-9137-1e3589f38128",                        [{"alignmentgroup":"True","hovertemplate":"age=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[36.0,28.0,39.0,24.0,34.0,38.0,25.0,28.0,29.0,28.0,27.0,27.0,28.0,34.0,31.0,27.0,25.0,29.0,26.0,24.0,24.0,21.0,23.0,29.0,32.0,29.0,30.0,27.0,27.0,28.0,22.0,35.0,29.0,24.0,30.0,30.0,34.0,25.0,27.0,27.0,25.0,30.0,37.0,27.0,23.0,31.0,28.0,23.0,24.0,23.0,24.0,27.0,31.0,33.0,29.0,25.0,23.0,34.0,24.0,27.0,27.0,26.0,26.0,33.0,24.0,24.0,26.0,25.0,22.0,25.0,29.0,24.0,24.0,23.0,29.0,31.0,34.0,22.0,18.0,31.0,30.0,39.0,31.0,36.0,32.0,28.0,22.0,28.0,26.0,30.0,23.0,33.0,26.0,30.0,37.0,24.0,31.0,33.0,29.0,33.0,28.0,26.0,25.0,24.0,34.0,31.0,31.0,24.0,28.0,30.0,32.0,25.0,32.0,29.0,24.0,22.0,32.0,34.0,28.0,29.0,28.0,31.0,26.0,24.0,26.0,27.0,32.0,25.0,28.0,26.0,29.0,23.0,25.0,31.0,32.0,33.0,22.0,25.0,33.0,24.0,25.0,27.0,27.0,30.0,24.0,29.0,26.0,22.0,27.0,26.0,38.0,24.0,31.0,25.0,25.0,30.0,25.0,27.0,35.0,20.0,28.0,26.0,23.0,26.0,24.0,26.0,30.0,24.0,35.0,28.0,23.0,24.0,35.0,25.0,28.0,36.0,23.0,26.0,31.0,30.0,30.0,31.0,29.0,26.0,25.0,23.0,31.0,24.0,26.0,33.0,38.0,24.0,29.0,25.0,26.0,37.0,36.0,25.0,30.0,27.0,26.0,27.0,34.0,40.0,33.0,27.0,31.0,24.0,23.0,29.0,32.0,29.0,27.0,27.0,31.0,33.0,23.0,24.0,26.0,35.0,24.0,22.0,30.0,27.0,27.0,33.0,36.0,21.0,33.0,27.0,31.0,26.0,29.0,25.0,31.0,27.0,35.0,23.0,26.0,25.0,20.0,24.0,25.0,27.0,24.0,25.0,29.0,30.0,23.0,33.0,24.0,29.0,22.0,22.0,21.0,24.0,23.0,29.0,31.0,26.0,33.0,32.0,29.