# %% [markdown]
# <a href="https://colab.research.google.com/github/gunjan7858903606/gunjan/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Regression problem

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
# from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/Linear Regression - Sheet1.csv")
df
# Out:
#        X           Y
# 0      1    3.888889
# 1      2    4.555556
# 2      3    5.222222
# 3      4    5.888889
# 4      5    6.555556
# ..   ...         ...
# 295  296  200.555556
# 296  297  201.222222
# 297  298  201.888889
# 298  299    1.888889
# 299  300    1.888889
#
# [300 rows x 2 columns]

# %%
sns.scatterplot(data=df,x="X",y="Y")
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
x=df.drop(columns=["Y"])
y=df["Y"]

# %%
x.shape,y.shape
# Out:
# ((300, 1), (300,))

# %%
# train test split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=24)

# Defining the model
lr = LinearRegression()

# Fitting the model
lr.fit(x_train,y_train)

# Getting predictions on X_test
y_pred = lr.predict(x_test)
# print(y_pred)

# %%
x_train.head()
# Out:
#        X
# 65    66
# 179  180
# 142  143
# 31    32
# 216  217

# %%
d={'matric':[],'value':[]}
error_df=pd.DataFrame(data=d)
error_df
# Out:
# Empty DataFrame
# Columns: [matric, value]
# Index: []

# %%
from sklearn.metrics import mean_absolute_error
d = {"metric": ["MAE"],
     "value": [mean_absolute_error(y_test,y_pred)]}
temp_df = pd.DataFrame(data = d)
error_df = pd.concat([error_df,temp_df],ignore_index = True)
error_df
# Out:
#    matric     value metric
# 0     NaN  4.581576    MAE

# %%
from sklearn.metrics import mean_squared_error

d = {'metric': ["MSE"],
     'value': [mean_squared_error(y_test,y_pred)]}
temp_df = pd.DataFrame(data = d)
error_df = pd.concat([error_df,temp_df],ignore_index = True)
error_df
# Out:
#    matric       value metric
# 0     NaN    4.581576    MAE
# 1     NaN  651.751075    MSE

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1["y_test"]=y_test.reset_index(drop=True)
df1["y_pred"]=y_pred
df1.head()
# Out:
#        y_test      y_pred
# 0  125.888889  124.495961
# 1   39.888889   40.624660
# 2   77.888889   77.684072
# 3  127.888889  126.446456
# 4   20.555556   21.769871

# %%
df1["y_test-y_pred"] = df1["y_test"] - df1["y_pred"]
df1.head()
# Out:
#        y_test      y_pred  y_test-y_pred
# 0  125.888889  124.495961       1.392928
# 1   39.888889   40.624660      -0.735771
# 2   77.888889   77.684072       0.204817
# 3  127.888889  126.446456       1.442433
# 4   20.555556   21.769871      -1.214315

# %%
df1["squared_error"]=np.square(df1["y_test-y_pred"])
df1.head()
# Out:
#        y_test      y_pred  y_test-y_pred  squared_error
# 0  125.888889  124.495961       1.392928       1.940249
# 1   39.888889   40.624660      -0.735771       0.541359
# 2   77.888889   77.684072       0.204817       0.041950
# 3  127.888889  126.446456       1.442433       2.080612
# 4   20.555556   21.769871      -1.214315       1.474562

# %%
rss=df1["squared_error"].sum()
rss
# Out:
# 39105.06452120767

# %%
mean=df1["y_test"].mean()
mean
# Out:
# 100.4111111148

# %%
df1["y-ymean"]=df1["y_test"]-mean
df1.head()
# Out:
#        y_test      y_pred  y_test-y_pred  squared_error    y-ymean
# 0  125.888889  124.495961       1.392928       1.940249  25.477778
# 1   39.888889   40.624660      -0.735771       0.541359 -60.522222
# 2   77.888889   77.684072       0.204817       0.041950 -22.522222
# 3  127.888889  126.446456       1.442433       2.080612  27.477778
# 4   20.555556   21.769871      -1.214315       1.474562 -79.855556

# %%
df1["squared_tss_error"] = np.square(df1["y-ymean"])
df1.head()
# Out:
#        y_test      y_pred  y_test-y_pred  squared_error    y-ymean  \
# 0  125.888889  124.495961       1.392928       1.940249  25.477778
# 1   39.888889   40.624660      -0.735771       0.541359 -60.522222
# 2   77.888889   77.684072       0.204817       0.041950 -22.522222
# 3  127.888889  126.446456       1.442433       2.080612  27.477778
# 4   20.555556   21.769871      -1.214315       1.474562 -79.855556
#
#    squared_tss_error
# 0         649.117161
# 1        3662.939383
# 2         507.250494
# 3         755.028272
# 4        6376.909753

# %%
tss=df1["squared_tss_error"].sum()
tss
# Out:
# 188842.74816058838

# %%
rss
# Out:
# 39105.06452120767

# %%
r2=1-(rss/tss)
r2
# Out:
# 0.792922604113167

# %%
df1["abs_error"]=abs(df1["y_test-y_pred"])
df1.head()
# Out:
#        y_test      y_pred  y_test-y_pred  squared_error    y-ymean  \
# 0  125.888889  124.495961       1.392928       1.940249  25.477778
# 1   39.888889   40.624660      -0.735771       0.541359 -60.522222
# 2   77.888889   77.684072       0.204817       0.041950 -22.522222
# 3  127.888889  126.446456       1.442433       2.080612  27.477778
# 4   20.555556   21.769871      -1.214315       1.474562 -79.855556
#
#    squared_tss_error  abs_error
# 0         649.117161   1.392928
# 1        3662.939383   0.735771
# 2         507.250494   0.204817
# 3         755.028272   1.442433
# 4        6376.909753   1.214315

# %%
df1["abs_error"].mean()
# Out:
# 4.581576030794952

# %%
df1["sq_error"]=(df1["y_test-y_pred"])**2
df1.head()
# Out:
#        y_test      y_pred  y_test-y_pred  squared_error    y-ymean  \
# 0  125.888889  124.495961       1.392928       1.940249  25.477778
# 1   39.888889   40.624660      -0.735771       0.541359 -60.522222
# 2   77.888889   77.684072       0.204817       0.041950 -22.522222
# 3  127.888889  126.446456       1.442433       2.080612  27.477778
# 4   20.555556   21.769871      -1.214315       1.474562 -79.855556
#
#    squared_tss_error  abs_error  sq_error
# 0         649.117161   1.392928  1.940249
# 1        3662.939383   0.735771  0.541359
# 2         507.250494   0.204817  0.041950
# 3         755.028272   1.442433  2.080612
# 4        6376.909753   1.214315  1.474562

# %%
np.sqrt(df1["sq_error"].mean())
# Out:
# 25.529415883514865

# %%
d = {'metric': ["RMSE"],
     'value': [np.sqrt(mean_squared_error(y_test,y_pred))]}
temp_df = pd.DataFrame(data = d)
error_df = pd.concat([error_df,temp_df],ignore_index = True)
error_df
# Out:
#    matric       value metric
# 0     NaN    4.581576    MAE
# 1     NaN  651.751075    MSE
# 2     NaN   25.529416   RMSE

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)

d = {'metric': ["R2"],
     'value': [r2]}
temp_df = pd.DataFrame(data = d)
error_df = pd.concat([error_df,temp_df],ignore_index = True)
error_df
# Out:
#    matric       value metric
# 0     NaN    4.581576    MAE
# 1     NaN  651.751075    MSE
# 2     NaN   25.529416   RMSE
# 3     NaN    0.792923     R2

# %%
from  sklearn.metrics import r2_score
n=x_train.shape[0]
k=x_train.shape[1]
r2=r2_score(y_test,y_pred)

adj_r2=1-((1-r2)*(n-1)/(n-k-1))
r2,adj_r2
# Out:
# (0.792922604113167, 0.7920525310212054)

# %%
d = {'metric': ["adj R2"],
     'value': [adj_r2]}
temp_df = pd.DataFrame(data = d)
error_df = pd.concat([error_df,temp_df],ignore_index = True)
error_df
# Out:
#    matric       value  metric
# 0     NaN    4.581576     MAE
# 1     NaN  651.751075     MSE
# 2     NaN   25.529416    RMSE
# 3     NaN    0.792923      R2
# 4     NaN    0.792053  adj R2
# 5     NaN    0.792053  adj R2

# %%
x = np.random.rand(200, 1) + 0.3

# %%
x.shape
# Out:
# (200, 1)

# %%
x.ndim
# Out:
# 2

# %%
y = 15*x**2 - 20*x + 19 + (np.random.randn(200, 1))*0.5
y.shape
# Out:
# (200, 1)

# %%
poly_df = pd.DataFrame()
poly_df["X"] = x.flatten()
poly_df["y"] = y.flatten()
poly_df.head()
# Out:
#           X          y
# 0  0.569357  12.323263
# 1  0.507598  13.518768
# 2  0.815874  12.860784
# 3  0.754894  12.142529
# 4  1.150380  15.563085

# %%
plt.scatter(poly_df["X"], poly_df["y"])
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
x=poly_df.drop(columns=["y"])
y=poly_df["y"]
x.shape,y.shape
# Out:
# ((200, 1), (200,))

# %%
# Train test split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=24)

print(f'Shape of x_train -: {x_train.shape}')
print(f'Shape of x_valid -: {x_test.shape}')
print(f'Shape of y_train -: {y_train.shape}')
print(f'Shape of y_valid -: {y_test.shape}')
# Out:
# Shape of x_train -: (160, 1)
# Shape of x_valid -: (40, 1)
# Shape of y_train -: (160,)
# Shape of y_valid -: (40,)

# %%
# Defining the model
lr = LinearRegression()

# Fitting the model
lr.fit(x_train,y_train)

# Getting predictions on X_test
y_pred = lr.predict(x_test)

# %%
# Calculating the r2 score
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.566574550295742

# %%
plt.plot(x_train, lr.predict(x_train), c ="red")
plt.scatter(x_train,y_train, c = "blue")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
plt.plot(x_train, lr.predict(x_train), c ="red")
# plt.plot(x_test, lr.predict(x_test), c ="green")
plt.scatter(x_train,y_train, c = "blue")
plt.scatter(x_test,y_test, c = "green")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
# Polynomial Linear Regression of degree 2
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)

x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# %%
x_train.head()
# Out:
#             X
# 5    1.196113
# 154  1.289971
# 173  0.978961
# 187  0.383728
# 108  1.252991

# %%
pd.DataFrame(x_train_poly).head()
# Out:
#      0         1         2
# 0  1.0  1.196113  1.430686
# 1  1.0  1.289971  1.664025
# 2  1.0  0.978961  0.958364
# 3  1.0  0.383728  0.147247
# 4  1.0  1.252991  1.569987

# %%
# Defining the model
poly_lr = LinearRegression()

# Fitting the model
poly_lr.fit(x_train_poly,y_train)

# Getting predictions on X_test
y_pred_poly = poly_lr.predict(x_test_poly)

# %%
# Calculating the r2 score
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_poly)
# Out:
# 0.9233328213569675

# %%
plt.plot(x_train, poly_lr.predict(x_train_poly), c ="red")
# plt.plot(x_test, lr.predict(x_test), c ="green")
plt.scatter(x_train,y_train, c = "blue")
plt.scatter(x_test,y_test, c = "green")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
d = {"x_train":x_train["X"].reset_index(drop=True), "y_train_pred_poly" : pd.Series(poly_lr.predict(x_train_poly))}
temp_df = pd.DataFrame(data = d)

sns.lineplot(data=temp_df, x="x_train", y="y_train_pred_poly", color = "red", label = "Prediction")
plt.scatter(x_train,y_train, c = "blue", label="train_data")
plt.scatter(x_test,y_test, c = "green", label="test_data")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
poly_lr.predict(x_train_poly).shape
# Out:
# (160,)

# %%
y_train.shape
# Out:
# (160,)
